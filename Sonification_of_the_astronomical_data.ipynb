# %% [markdown]
# <a href="https://colab.research.google.com/github/hafiashafqat/My_projects-python4physics-/blob/main/Sonification_of_the_astronomical_data.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Sonification of the astronomical data

# %% [markdown]
# Sonifying the properties of the Sun

# %% [markdown]
# For temperature

# %% [markdown]
# importing libraries and connecting to drive

# %%
import numpy as np
import matplotlib.pyplot as plt
from google.colab import files
from scipy.io.wavfile import write
from google.colab import drive
import os
drive.mount('/content/drive')
from scipy.constants import Wien
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %% [markdown]
# Wein's Displacement law

# %%
Temp= 6000  #in K
b = Wien  # in meters·Kelvin
maximum_wavelength = b/Temp
print(maximum_wavelength)
# Out:
# 4.829619925308621e-07

# %% [markdown]
# Converting wavelength into frequency

# %%
c= 3*10**8  #m/s
Frequency = c/maximum_wavelength
print(Frequency)
# Out:
# 621166892301218.8

# %% [markdown]
# Scaling down the frequency as it is too high

# %%
def F_sound(Frequency):
    return Frequency / 10**10  # This scales the frequency down

# Now call the function and print the result
Frequency = 621166892301218.8 # example frequency in Hz (visible light)
scaled = F_sound(Frequency)
print(f"Scaled sound frequency: {scaled} Hz")
# Out:
# Scaled sound frequency: 62116.689230121876 Hz

# %%
def F_sound(Frequency):
    return Frequency / 1e12  # or 1e13

Frequency = 6.211e14
scaled = F_sound(Frequency)
print(f"Audible-range scaled frequency: {scaled:.2f} Hz")
# Out:
# Audible-range scaled frequency: 621.10 Hz

# %% [markdown]
# Generating the Sound at this frequency

# %%
import numpy as np
from scipy.io.wavfile import write
from pydub import AudioSegment
from google.colab import drive
import os
from IPython.display import Audio

# Mount Google Drive
drive.mount('/content/drive')

# Calculate exact frequency for 6000K Sun-like star
SUN_TEMP = 6000  # Kelvin
BASE_FREQ = SUN_TEMP * 0.01  # 6000 * 0.01 = 60.00 Hz (inaudible)
SCALED_FREQ = 621.10  # Hz (audible scaled version)

# Audio parameters
SAMPLE_RATE = 44100  # Standard CD quality
DURATION = 3.5  # Middle of requested range (seconds)
FADE_START = 1.5  # When fading begins (seconds)

# Musical pitch information (A4 = 440Hz reference)
NOTE_NAME = "D♯5/E♭5"  # Closest musical note
CENT_DEVIATION = "+31.3 cents"  # How far from perfect tuning

def generate_solar_sound():
    t = np.linspace(0, DURATION, int(SAMPLE_RATE * DURATION), False)

    # Create dynamic frequency (from 621.10Hz down to 500Hz)
    freq = np.linspace(SCALED_FREQ, 500, len(t))

    # Create volume envelope (1.5s constant, then fade)
    volume = np.ones_like(t)
    fade_time = DURATION - FADE_START
    fade_mask = t > FADE_ST
    # Play directly in Colab
Audio(wave, rate=sr)
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>
